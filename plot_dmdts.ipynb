# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
execfile('/Users/lawsmith/Dropbox/jYT/my_settings.py')
plt.rcParams['legend.fontsize'] = 16
plt.rcParams['font.size'] = 12

# %%
fig, ax = plt.subplots()
x, y = np.loadtxt('/Users/lawsmith/Dropbox/RS/fend_results/m1_0_p10_b3_0_0060_ev.dat', skiprows=1, unpack=True)
ax.plot(x, y, c='C0', label='p10_b3.0, 48k, fend, chk60')
x, y = np.loadtxt('/Users/lawsmith/Dropbox/RS/fend_results/m1_0_p10_b3_0_24k_0060_ev.dat', skiprows=1, unpack=True)
ax.plot(x, y, c='C3', label='p10_b3.0, 24k, fend, chk60')
#x, y = np.loadtxt('/Users/lawsmith/Dropbox/RS/hyades_results/dmdts/data/m1_0_p10_b3_0_0060_ev.dat', skiprows=1, unpack=True)
#ax.plot(x, y, c='C1', label='p10_b3.0, 24k, hyades, chk60')
#x, y = np.loadtxt('/Users/lawsmith/Dropbox/RS/hyades_results/dmdts/data/m1_0_p10_b3_0_256_0057_ev.dat', skiprows=1, unpack=True)
#ax.plot(x, y, c='C2', label='p10_b3.0, 48k, hyades, chk57')
ax.set_xlim(-2, 2)
ax.legend()
fig.tight_layout()

# %%
fig, ax = plt.subplots()
x, y = np.loadtxt('/Users/lawsmith/Dropbox/RS/fend_results/m1_0_p16_b3_0/m1_0_p16_b3_0_0060_ev.dat', skiprows=1, unpack=True)
ax.plot(x, y, c='C0', label='p16_b3.0, 48k, fend, chk60')
x, y = np.loadtxt('/Users/lawsmith/Dropbox/RS/fend_results/m1_0_p16_b3_0_24k/m1_0_p16_b3_0_24k_0060_ev.dat', skiprows=1, unpack=True)
ax.plot(x, y, c='C3', label='p16_b3.0, 24k, fend, chk60')
x, y = np.loadtxt('/Users/lawsmith/Dropbox/RS/fend_results/m1_0_p16_b3_0_12k/m1_0_p16_b3_0_12k_0060_ev.dat', skiprows=1, unpack=True)
ax.plot(x, y, c='C2', label='p16_b3.0, 12k, fend, chk60')
x, y = np.loadtxt('/Users/lawsmith/Dropbox/RS/fend_results/m1_0_p16_b3_0_12k/m1_0_p16_b3_0_12k_0040_ev.dat', skiprows=1, unpack=True)
ax.plot(x, y, c='C2', ls='--', label='p16_b3.0, 12k, fend, chk40')
x, y = np.loadtxt('/Users/lawsmith/Dropbox/RS/hyades_results/dmdts/data/m1_0_p16_b3_0_0060_ev.dat', skiprows=1, unpack=True)
ax.plot(x, y, c='C7', label='p16_b3.0, 24k, hyades, chk60')
ax.set_xlim(-2, 2)
ax.legend()
fig.tight_layout()

# %%
fig, ax = plt.subplots()
x, y = np.loadtxt('/Users/lawsmith/Dropbox/RS/fend_results/43_b2_0_12k_flash/43_b2_0_12k_flash_0040_ev.dat', skiprows=1, unpack=True)
ax.plot(x, y, c='C0', ls='--', label='43_b2.0_12k_flash, fend, chk40')
x, y = np.loadtxt('/Users/lawsmith/Dropbox/RS/fend_results/43_b2_0_12k_flash/43_b2_0_12k_flash_0080_ev.dat', skiprows=1, unpack=True)
ax.plot(x, y, c='C1', ls='--', label='43_b2.0_12k_flash, fend, chk80')
#x, y = np.loadtxt('/Users/lawsmith/Dropbox/RS/fend_results/43_b2_0_12k/43_b2_0_12k_0080_ev.dat', skiprows=1, unpack=True)
#ax.plot(x, y, c='C2', label='43_b2.0_12k, fend, chk80')
#x, y = np.loadtxt('/Users/lawsmith/Dropbox/RS/fend_results/43_b2_0_48k/43_b2_0_48k_intel_0080_ev.dat', skiprows=1, unpack=True)
#ax.plot(x, y, c='C3', label='43_b2.0_48k, fend, chk80')
x, y = np.loadtxt('/Users/lawsmith/Dropbox/Archived/tde-data/Guillochon2013_dmdts/4-3/2.000.dat', skiprows=1, unpack=True)
ax.plot(x, y, c='C7', label='GRR2013')
ax.set_xlim(-2, 2)
ax.legend()
fig.tight_layout()
